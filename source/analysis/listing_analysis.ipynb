# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Correlation analysis

# %%
cor = dt.corr()
cor
# Out:
#                              review_scores_rating  review_scores_accuracy  \
# review_scores_rating                     1.000000                0.888206
# review_scores_accuracy                   0.888206                1.000000
# review_scores_cleanliness                0.851166                0.823138
# review_scores_checkin                    0.772641                0.775828
# review_scores_communication              0.856812                0.852133
# review_scores_location                   0.654785                0.663916
# review_scores_value                      0.853400                0.835398
# price                                    0.068351                0.050969
#
#                              review_scores_cleanliness  review_scores_checkin  \
# review_scores_rating                          0.851166               0.772641
# review_scores_accuracy                        0.823138               0.775828
# ...

# %%
cmap = sns.diverging_palette(200,20,sep=20,as_cmap=True)
plt.figure(figsize=(8, 6))
# sns.heatmap(cor.iloc[:-1,:-1], annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
sns.heatmap(cor.iloc[:-1,:-1], annot=True, cmap=cmap, fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Airbnb')
plt.show()

# %% [markdown]
# # Feature Importance

# %%
fi = pd.read_csv('/Users/hongyingyue/Desktop/CMPT732_Lab1/Project/inside_airbnb/vancouver/listing_importance/part-00000-5d339581-b266-4ccd-a1e1-33086a08f7e9-c000.csv')
fi
# Out:
#                        feature  importance
# 0                  room_type_i    0.021864
# 1       review_scores_accuracy    0.176444
# 2    review_scores_cleanliness    0.094490
# 3        review_scores_checkin    0.038003
# 4  review_scores_communication    0.106437
# 5       review_scores_location    0.036639
# 6          review_scores_value    0.406352
# 7                        price    0.119770

# %%
fi_reshape=fi.sort_values(by="importance",ascending=False)
plt.figure(figsize=(8, 6))
sns.barplot(y='feature',x='importance', data=fi_reshape, orient="h")
plt.title('Feature Importance to Review rating')
plt.show()
